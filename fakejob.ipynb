# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("fake_job_postings.csv") #loading the csv file
df    #printing the csv file data
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
df.dtypes  #finding the data types of each column
# Out:
# job_id                  int64
# title                  object
# location               object
# department             object
# salary_range           object
# company_profile        object
# description            object
# requirements           object
# benefits               object
# telecommuting           int64
# has_company_logo        int64
# has_questions           int64
# employment_type        object
# required_experience    object
# required_education     object
# industry               object
# function               object
# fraudulent              int64
# dtype: object

# %%
df.describe(include='all')  #getting the description of all the column values
# Out:
#               job_id                    title         location department  \
# count   17880.000000                    17880            17534       6333
# unique           NaN                    11231             3105       1337
# top              NaN  English Teacher Abroad   GB, LND, London      Sales
# freq             NaN                      311              718        551
# mean     8940.500000                      NaN              NaN        NaN
# std      5161.655742                      NaN              NaN        NaN
# min         1.000000                      NaN              NaN        NaN
# 25%      4470.750000                      NaN              NaN        NaN
# 50%      8940.500000                      NaN              NaN        NaN
# 75%     13410.250000                      NaN              NaN        NaN
# max     17880.000000                      NaN              NaN        NaN
#
#        salary_range                                    company_profile  \
# ...

# %%
df.replace(" ", np.nan, inplace= True)
df.head(10)
# Out:
#    job_id                                      title               location  \
# 0       1                           Marketing Intern       US, NY, New York
# 1       2  Customer Service - Cloud Video Production         NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)          US, IA, Wever
# 3       4          Account Executive - Washington DC     US, DC, Washington
# 4       5                        Bill Review Manager     US, FL, Fort Worth
# 5       6                           Accounting Clerk               US, MD,
# 6       7                      Head of Content (m/f)         DE, BE, Berlin
# 7       8           Lead Guest Service Specialist     US, CA, San Francisco
# 8       9                                 HP BSM SME      US, FL, Pensacola
# 9      10    Customer Service Associate - Part Time         US, AZ, Phoenix
#
#    department salary_range                                    company_profile  \
# ...

# %%
df.info()  #inforatioin about all the entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
missing_value= df.isnull()   #checking the null value in the dataset if null return True else False
for column in df:
    missing_value[column].value_counts()
    " "

# %%
df['location'].value_counts().idxmax()
# Finding the max count of location to replace the null value from that location under this section
# Out:
# 'GB, LND, London'

# %%
df['location'].replace(np.nan, 'GB LND London')
#replacing the null values of location column from the max frequency value of location column
# Out:
# 0            US, NY, New York
# 1              NZ, , Auckland
# 2               US, IA, Wever
# 3          US, DC, Washington
# 4          US, FL, Fort Worth
#                  ...
# 17875         CA, ON, Toronto
# 17876    US, PA, Philadelphia
# 17877         US, TX, Houston
# 17878           NG, LA, Lagos
# 17879       NZ, N, Wellington
# Name: location, Length: 17880, dtype: object

# %%
df['department'].value_counts().idxmax()
# Finding the max count of department to replace the null value from that department under this section
# Out:
# 'Sales'

# %%
df['department'].replace(np.nan, 'Sales')
#replacing the null values of department column from the max frequency value of department column
# Out:
# 0          Marketing
# 1            Success
# 2              Sales
# 3              Sales
# 4              Sales
#             ...
# 17875          Sales
# 17876     Accounting
# 17877          Sales
# 17878          Sales
# 17879    Engineering
# Name: department, Length: 17880, dtype: object

# %%
df['company_profile'].value_counts().idxmax()
# Finding the max count of company_profile to replace the null value from that company_profile under this section
# Out:
# 'We help teachers get safe &amp; secure jobs abroad :)'

# %%
#replacing the null values of company_profile column from the max frequency value of company_profile column
df['company_profile'].replace(np.nan, 'We help teachers get safe &amp; secure jobs abroad :)')
# Out:
# 0        We're Food52, and we've created a groundbreaki...
# 1        90 Seconds, the worlds Cloud Video Production ...
# 2        Valor Services provides Workforce Solutions th...
# 3        Our passion for improving quality of life thro...
# 4        SpotSource Solutions LLC is a Global Human Cap...
#                                ...
# 17875    Vend is looking for some awesome new talent to...
# 17876    WebLinc is the e-commerce platform and service...
# 17877    We Provide Full Time Permanent Positions for m...
# 17878    We help teachers get safe &amp; secure jobs ab...
# 17879    Vend is looking for some awesome new talent to...
# Name: company_profile, Length: 17880, dtype: object

# %%
# Finding the max count of description to replace the null value from that description under this section
df['description'].value_counts().idxmax()
# Out:
# 'Play with kids, get paid for it\xa0Love travel? Jobs in Asia$1,500+ USD monthly ($200 Cost of living)Housing provided (Private/Furnished)Airfare ReimbursedExcellent for student loans/credit cardsGabriel Adkins : #URL_ed9094c60184b8a4975333957f05be37e69d3cdb68decc9dd9a4242733cfd7f7##URL_75db76d58f7994c7db24e8998c2fc953ab9a20ea9ac948b217693963f78d2e6b#12 month contract : Apply today\xa0'

# %%
#replacing the null values of description column from the max frequency value of description column
df['description'].replace(np.nan, 'Play with kids, get paid for it Love travel? Jobs in Asia$1,500+ USD monthly ($200 Cost of living)Housing provided (Private/Furnished)Airfare ReimbursedExcellent for student loans/credit cardsGabriel Adkins : #URL_ed9094c60184b8a4975333957f05be37e69d3cdb68decc9dd9a4242733cfd7f7##URL_75db76d58f7994c7db24e8998c2fc953ab9a20ea9ac948b217693963f78d2e6b#12 month contract : Apply today')
# Out:
# 0        Food52, a fast-growing, James Beard Award-winn...
# 1        Organised - Focused - Vibrant - Awesome!Do you...
# 2        Our client, located in Houston, is actively se...
# 3        THE COMPANY: ESRI – Environmental Systems Rese...
# 4        JOB TITLE: Itemization Review ManagerLOCATION:...
#                                ...
# 17875    Just in case this is the first time you’ve vis...
# 17876    The Payroll Accountant will focus primarily on...
# 17877    Experienced Project Cost Control Staff Enginee...
# 17878    Nemsia Studios is looking for an experienced v...
# 17879    Who are we?Vend is an award winning web based ...
# Name: description, Length: 17880, dtype: object

# %%
# Finding the max count of requirements to replace the null value from that requirements under this section
df['requirements'].value_counts().idxmax()
# Out:
# 'University degree required.\xa0TEFL / TESOL / CELTA or teaching experience preferred but not necessaryCanada/US passport holders only'

# %%
#replacing the null values of requirements column from the max frequency value of requirements column
df['requirements'].replace(np.nan, 'University degree required. TEFL / TESOL / CELTA or teaching experience preferred but not necessaryCanada/US passport holders only')
# Out:
# 0        Experience with content management systems a m...
# 1        What we expect from you:Your key responsibilit...
# 2        Implement pre-commissioning and commissioning ...
# 3        EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4        QUALIFICATIONS:RN license in the State of Texa...
#                                ...
# 17875    To ace this role you:Will eat comprehensive St...
# 17876    - B.A. or B.S. in Accounting- Desire to have f...
# 17877    At least 12 years professional experience.Abil...
# 17878    1. Must be fluent in the latest versions of Co...
# 17879    We want to hear from you if:You have an in-dep...
# Name: requirements, Length: 17880, dtype: object

# %%
# Finding the max count of benefits to replace the null value from that benefits under this section
df['benefits'].value_counts().idxmax()
# Out:
# 'See job description'

# %%
#replacing the null values of benefits column from the max frequency value of benefits column
df['benefits'].replace(np.nan, 'See job description')
# Out:
# 0                                      See job description
# 1        What you will get from usThrough being part of...
# 2                                      See job description
# 3        Our culture is anything but corporate—we have ...
# 4                                    Full Benefits Offered
#                                ...
# 17875    What can you expect from us?We have an open cu...
# 17876    Health &amp; WellnessMedical planPrescription ...
# 17877                                  See job description
# 17878    Competitive salary (compensation will be based...
# 17879                                  See job description
# Name: benefits, Length: 17880, dtype: object

# %%
# Finding the max count of employment_type to replace the null value from that employment_type under this section
df['employment_type'].value_counts().idxmax()
# Out:
# 'Full-time'

# %%
#replacing the null values of employment_type column from the max frequency value of employment_type column
df['employment_type'].replace(np.nan, 'Full-time')
# Out:
# 0            Other
# 1        Full-time
# 2        Full-time
# 3        Full-time
# 4        Full-time
#            ...
# 17875    Full-time
# 17876    Full-time
# 17877    Full-time
# 17878     Contract
# 17879    Full-time
# Name: employment_type, Length: 17880, dtype: object

# %%
# Finding the max count of required_experience to replace the null value from that required_experience under this section
df['required_experience'].value_counts().idxmax()
# Out:
# 'Mid-Senior level'

# %%
#replacing the null values of required_experience column from the max frequency value of required_experience column
df['required_experience'].replace(np.nan, 'Mid-Senior level')
# Out:
# 0              Internship
# 1          Not Applicable
# 2        Mid-Senior level
# 3        Mid-Senior level
# 4        Mid-Senior level
#                ...
# 17875    Mid-Senior level
# 17876    Mid-Senior level
# 17877    Mid-Senior level
# 17878      Not Applicable
# 17879    Mid-Senior level
# Name: required_experience, Length: 17880, dtype: object

# %%
# Finding the max count of required_education to replace the null value from that required_education under this section
df['required_education'].value_counts().idxmax()
# Out:
# "Bachelor's Degree"

# %%
#replacing the null values of required_education column from the max frequency value of required_education column
df['required_education'].replace(np.nan, 'Bachelor\'s degree')
# Out:
# 0        Bachelor's degree
# 1        Bachelor's degree
# 2        Bachelor's degree
# 3        Bachelor's Degree
# 4        Bachelor's Degree
#                ...
# 17875    Bachelor's degree
# 17876    Bachelor's Degree
# 17877    Bachelor's degree
# 17878         Professional
# 17879    Bachelor's degree
# Name: required_education, Length: 17880, dtype: object

# %%
# Finding the max count of industry to replace the null value from that industry under this section
df['industry'].value_counts().idxmax()
# Out:
# 'Information Technology and Services'

# %%
#replacing the null values of industry column from the max frequency value of industry column
df['industry'].replace(np.nan, 'Information Technology and Services')
# Out:
# 0        Information Technology and Services
# 1                  Marketing and Advertising
# 2        Information Technology and Services
# 3                          Computer Software
# 4                     Hospital & Health Care
#                         ...
# 17875                      Computer Software
# 17876                               Internet
# 17877    Information Technology and Services
# 17878                         Graphic Design
# 17879                      Computer Software
# Name: industry, Length: 17880, dtype: object

# %%
# Finding the max count of function to replace the null value from that function under this section
df['function'].value_counts().idxmax()
# Out:
# 'Information Technology'
